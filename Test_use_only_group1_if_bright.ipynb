# %%
import numpy as np
import matplotlib.pyplot as plt

from jwst import datamodels
from stdatamodels.jwst.datamodels import dqflags

from helpers.miri_helpers import miri_detector1

# %%
import jwst
print(jwst.__version__)
# Out:
# 1.16.1.dev129+g7317c9f0c

# %%
rawfile = "jw02729002001_02107_00001_mirimage_uncal.fits"

# %%
# run detector1 and save the linearized ramp
miri_detector1([f"data/{rawfile}"], "data", save_jump_info=True, bright_use_group1=True, no_grow_saturation=False)
# Out:
# 2024-11-05 08:53:18,208 - stpipe - INFO - PARS-EMICORRSTEP parameters found: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_pars-emicorrstep_0002.asdf
# 2024-11-05 08:53:18,218 - stpipe - INFO - PARS-DARKCURRENTSTEP parameters found: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_pars-darkcurrentstep_0001.asdf
# 2024-11-05 08:53:18,226 - stpipe - INFO - PARS-JUMPSTEP parameters found: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_pars-jumpstep_0004.asdf
# 2024-11-05 08:53:18,233 - CRDS - ERROR -  Error determining best reference for 'pars-cleanflickernoisestep'  =   Unknown reference type 'pars-cleanflickernoisestep'
# 2024-11-05 08:53:18,235 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_pars-detector1pipeline_0008.asdf
# 2024-11-05 08:53:18,248 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2024-11-05 08:53:18,249 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2024-11-05 08:53:18,250 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2024-11-05 08:53:18,251 - stpipe.Detector1Pipeline.emicorr - INFO - EmiCorrStep instance created.
# 2024-11-05 08:53:18,252 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2024-11-05 08:53:18,252 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2024-11-05 08:53:18,253 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2024-11-05 08:53:18,254 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2024-11-05 08:53:18,254 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2024-11-05 08:53:18,255 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2024-11-05 08:53:18,256 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2024-11-05 08:53:18,256 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2024-11-05 08:53:18,257 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2024-11-05 08:53:18,257 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2024-11-05 08:53:18,258 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2024-11-05 08:53:18,259 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2024-11-05 08:53:18,260 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2024-11-05 08:53:18,261 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - CleanFlickerNoiseStep instance created.
# 2024-11-05 08:53:18,262 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2024-11-05 08:53:18,263 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2024-11-05 08:53:18,421 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('data/jw02729002001_02107_00001_mirimage_uncal.fits',).
# data/jw02729002001_02107_00001_mirimage_uncal.fits
# 2024-11-05 08:53:18,435 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: data
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_calibrated_ramp: True
#   steps:
#     group_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     emicorr:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_intermediate_results: False
#       user_supplied_reffile: None
#       nints_to_phase: None
#       nbins: None
#       scale_reference: True
#       onthefly_corr_freq: None
#       use_n_cycles: 3
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       n_pix_grow_sat: 1
#       use_readpatt: True
#     ipc:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     superbias:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       odd_even_columns: True
#       use_side_ref_pixels: True
#       side_smoothing_length: 11
#       side_gain: 1.0
#       odd_even_rows: True
#       ovr_corr_mitigation_ftr: 3.0
#       preserve_irs2_refpix: False
#       irs2_mean_subtraction: False
#     rscd:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       type: baseline
#     firstframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bright_use_group1: True
#     lastframe:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       dark_output: None
#       average_dark_current: 1.0
#     reset:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#     persistence:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       input_trapsfilled: ''
#       flag_pers_cutoff: 40.0
#       save_persistence: False
#       save_trapsfilled: True
#       modify_input: False
#     charge_migration:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       signal_threshold: 25000.0
#     jump:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       rejection_threshold: 5.0
#       three_group_rejection_threshold: 6.0
#       four_group_rejection_threshold: 5.0
#       maximum_cores: half
#       flag_4_neighbors: True
#       max_jump_to_flag_neighbors: 1000
#       min_jump_to_flag_neighbors: 30
#       after_jump_flag_dn1: 500
#       after_jump_flag_time1: 15
#       after_jump_flag_dn2: 1000
#       after_jump_flag_time2: 3000
#       expand_large_events: False
#       min_sat_area: 1
#       min_jump_area: 0
#       expand_factor: 0
#       use_ellipses: False
#       sat_required_snowball: False
#       min_sat_radius_extend: 0.0
#       sat_expand: 0
#       edge_size: 0
#       mask_snowball_core_next_int: True
#       snowball_time_masked_next_int: 4000
#       find_showers: False
#       extend_snr_threshold: 3.0
#       extend_min_area: 50
#       extend_inner_radius: 1
#       extend_outer_radius: 2.6
#       extend_ellipse_expand_ratio: 1.1
#       time_masked_after_shower: 30
#       min_diffs_single_pass: 10
#       max_extended_radius: 200
#       minimum_groups: 3
#       minimum_sigclip_groups: 100
#       only_use_ints: True
#     clean_flicker_noise:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       fit_method: median
#       fit_by_channel: False
#       background_method: median
#       background_box_size: None
#       mask_science_regions: False
#       n_sigma: 2.0
#       fit_histogram: False
#       single_mask: True
#       user_mask: None
#       save_mask: False
#       save_background: False
#       save_noise: False
#     ramp_fit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: True
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       algorithm: OLS_C
#       int_name: ''
#       save_opt: True
#       opt_name: ''
#       suppress_one_group: True
#       maximum_cores: '1'
#     gain_scale:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
# 2024-11-05 08:53:18,535 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw02729002001_02107_00001_mirimage_uncal.fits' reftypes = ['dark', 'emicorr', 'gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2024-11-05 08:53:18,538 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits'.
# 2024-11-05 08:53:18,538 - stpipe.Detector1Pipeline - INFO - Prefetch for EMICORR reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_emicorr_0002.asdf'.
# 2024-11-05 08:53:18,538 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0046.fits'.
# 2024-11-05 08:53:18,538 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0041.fits'.
# 2024-11-05 08:53:18,539 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits'.
# 2024-11-05 08:53:18,539 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2024-11-05 08:53:18,539 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits'.
# 2024-11-05 08:53:18,539 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits'.
# 2024-11-05 08:53:18,540 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits'.
# 2024-11-05 08:53:18,540 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/kgordon/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits'.
# 2024-11-05 08:53:18,540 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2024-11-05 08:53:18,540 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2024-11-05 08:53:18,541 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2024-11-05 08:53:18,541 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2024-11-05 08:53:18,842 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:18,848 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2024-11-05 08:53:18,849 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2024-11-05 08:53:18,850 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2024-11-05 08:53:19,001 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:19,013 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_mask_0036.fits
# 2024-11-05 08:53:19,085 - stpipe.Detector1Pipeline.dq_init - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:19,099 - stpipe.Detector1Pipeline.dq_init - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:19,141 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2024-11-05 08:53:19,290 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:19,355 - stpipe.Detector1Pipeline.emicorr - INFO - Using CRDS reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_emicorr_0002.asdf
# 2024-11-05 08:53:19,369 - stpipe.Detector1Pipeline.emicorr - INFO - Using reference file to get subarray case.
# 2024-11-05 08:53:19,369 - stpipe.Detector1Pipeline.emicorr - INFO - With configuration: Subarray=FULL, Read_pattern=FASTR1, Detector=MIRIMAGE
# 2024-11-05 08:53:19,370 - stpipe.Detector1Pipeline.emicorr - INFO - Will correct data for the following 1 frequencies:
# 2024-11-05 08:53:19,370 - stpipe.Detector1Pipeline.emicorr - INFO -    ['Hz10']
# 2024-11-05 08:53:19,370 - stpipe.Detector1Pipeline.emicorr - INFO - Correcting for frequency: 10.039216 Hz  (1 out of 1)
# 2024-11-05 08:53:19,391 - stpipe.Detector1Pipeline.emicorr - INFO - Subtracting self-superbias from each group of each integration and
# 2024-11-05 08:53:19,392 - stpipe.Detector1Pipeline.emicorr - INFO - doing phase calculation per integration
# 2024-11-05 08:53:20,584 - stpipe.Detector1Pipeline.emicorr - INFO - Calculating the phase amplitude for 500 bins
# 2024-11-05 08:53:23,573 - stpipe.Detector1Pipeline.emicorr - INFO - Using reference file to measure phase shift
# 2024-11-05 08:53:23,598 - stpipe.Detector1Pipeline.emicorr - INFO - Creating phased-matched noise model to subtract from data
# 2024-11-05 08:53:23,630 - stpipe.Detector1Pipeline.emicorr - INFO - Subtracting EMI noise from data
# 2024-11-05 08:53:24,183 - stpipe.Detector1Pipeline.emicorr - INFO - Step emicorr done
# 2024-11-05 08:53:24,336 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:24,348 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_saturation_0034.fits
# 2024-11-05 08:53:24,365 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:24,377 - stpipe.Detector1Pipeline.saturation - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:24,427 - stpipe.Detector1Pipeline.saturation - INFO - Using read_pattern with nframes 1
# 2024-11-05 08:53:25,630 - stpipe.Detector1Pipeline.saturation - INFO - Detected 240688 saturated pixels
# 2024-11-05 08:53:25,641 - stpipe.Detector1Pipeline.saturation - INFO - Detected 11 A/D floor pixels
# 2024-11-05 08:53:25,644 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2024-11-05 08:53:25,792 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:25,792 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2024-11-05 08:53:25,938 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:26,000 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrame Sub: bright_first_frame set, #216449 bright pixels using first frame
# 2024-11-05 08:53:26,001 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2024-11-05 08:53:26,149 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:26,204 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2024-11-05 08:53:26,350 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:26,362 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_reset_0077.fits
# 2024-11-05 08:53:26,409 - stpipe.Detector1Pipeline.reset - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:26,420 - stpipe.Detector1Pipeline.reset - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:26,515 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2024-11-05 08:53:26,682 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:26,695 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_linearity_0041.fits
# 2024-11-05 08:53:26,714 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword RESERVED_4 does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:26,723 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UNRELIABLE_RESET does not correspond to an existing DQ mnemonic, so will be ignored
# 2024-11-05 08:53:26,975 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2024-11-05 08:53:27,124 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:27,137 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_rscd_0017.fits
# 2024-11-05 08:53:27,216 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2024-11-05 08:53:27,363 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:27,376 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_dark_0103.fits
# 2024-11-05 08:53:28,531 - stpipe.Detector1Pipeline.dark_current - INFO - Using Poisson noise from average dark current 1.0 e-/sec
# 2024-11-05 08:53:28,532 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=4, ngroups=8, nframes=1, groupgap=0
# 2024-11-05 08:53:28,532 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=2, ngroups=360, nframes=1, groupgap=0
# 2024-11-05 08:53:29,110 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2024-11-05 08:53:29,261 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:29,262 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2024-11-05 08:53:29,409 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:29,409 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2024-11-05 08:53:29,557 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:29,615 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# 2024-11-05 08:53:29,615 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2024-11-05 08:53:29,623 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0046.fits
# 2024-11-05 08:53:29,639 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2024-11-05 08:53:29,732 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2024-11-05 08:53:29,762 - stpipe.Detector1Pipeline.jump - INFO - Creating 4 processes for jump detection
# 2024-11-05 08:53:33,185 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 3.45192 sec
# 2024-11-05 08:53:33,244 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 3.680520
# 2024-11-05 08:53:33,246 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2024-11-05 08:53:33,391 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step clean_flicker_noise running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_uncal.fits>,).
# 2024-11-05 08:53:33,392 - stpipe.Detector1Pipeline.clean_flicker_noise - INFO - Step skipped.
# 2024-11-05 08:53:33,570 - stpipe.Detector1Pipeline - INFO - Saved model in data/jw02729002001_02107_00001_mirimage_ramp.fits
# 2024-11-05 08:53:33,714 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(4, 8, 1024, 1032) from jw02729002001_02107_00001_mirimage_ramp.fits>,).
# 2024-11-05 08:53:33,783 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_readnoise_0085.fits
# 2024-11-05 08:53:33,783 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /home/kgordon/crds_cache/references/jwst/miri/jwst_miri_gain_0046.fits
# 2024-11-05 08:53:33,801 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = OLS_C
# 2024-11-05 08:53:33,801 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2024-11-05 08:53:35,163 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of multiprocessing slices: 1
# 2024-11-05 08:53:35,164 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 0
# 2024-11-05 08:53:35,165 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2024-11-05 08:53:36,511 - stpipe.Detector1Pipeline.ramp_fit - INFO - Ramp Fitting C Time: 1.3439912796020508
# 2024-11-05 08:53:36,980 - stpipe.Detector1Pipeline.ramp_fit - INFO - Saved model in data/jw02729002001_02107_00001_mirimage_fitopt.fits
# 2024-11-05 08:53:37,073 - stpipe.Detector1Pipeline.ramp_fit - INFO - Saved model in data/jw02729002001_02107_00001_mirimage_0_ramp_fit.fits
# 2024-11-05 08:53:37,159 - stpipe.Detector1Pipeline.ramp_fit - INFO - Saved model in data/jw02729002001_02107_00001_mirimage_1_ramp_fit.fits
# 2024-11-05 08:53:37,160 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2024-11-05 08:53:37,316 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(1024, 1032) from jw02729002001_02107_00001_mirimage_0_ramp_fit.fits>,).
# 2024-11-05 08:53:37,346 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2024-11-05 08:53:37,347 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2024-11-05 08:53:37,348 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2024-11-05 08:53:37,502 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(4, 1024, 1032) from jw02729002001_02107_00001_mirimage_1_ramp_fit.fits>,).
# 2024-11-05 08:53:37,525 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2024-11-05 08:53:37,525 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2024-11-05 08:53:37,527 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2024-11-05 08:53:37,619 - stpipe.Detector1Pipeline - INFO - Saved model in data/jw02729002001_02107_00001_mirimage_rateints.fits
# 2024-11-05 08:53:37,620 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2024-11-05 08:53:37,620 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1299.pmap
# 2024-11-05 08:53:37,682 - stpipe.Detector1Pipeline - INFO - Saved model in data/jw02729002001_02107_00001_mirimage_rate.fits
# 2024-11-05 08:53:37,683 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2024-11-05 08:53:37,683 - stpipe - INFO - Results used jwst version: 1.16.1.dev129+g7317c9f0c

# %%
obs = datamodels.open(f"data/{rawfile.replace('uncal', 'ramp')}")

# %%
# plot ramps
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
ax = axes.flatten()

groupnum = range(len(obs.data[0, :, 0, 0]))
for i in range(4):
    # find all the apprpriately flagged pixels
    svals = ((obs.groupdq[i, 1, :, :] & dqflags.group['SATURATED']) == 0) & ((obs.groupdq[i, 2, :, :] & dqflags.group['SATURATED']) > 0)

    tsize = svals.shape
    for j in range(tsize[0]):
        for k in range(tsize[1]):
            if svals[j, k]:
                ax[i].plot(groupnum, obs.data[i, :, j, k], "k-", alpha=0.02)
                break

ax[0].set_title("Integration 1")
ax[1].set_title("Integration 2")
ax[2].set_title("Integration 3")
ax[3].set_title("Integration 4")

axes[0, 0].set_ylabel("DN")
axes[1, 0].set_ylabel("DN")
axes[1, 1].set_xlabel("group #")
axes[1, 0].set_xlabel("group #")

fig.tight_layout()
plt.savefig("ramps_by_integration_onlygroup1.png")

# %%
# plot by integration
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
ax = axes.flatten()

for i in range(4):
    # find all the apprpriately flagged pixels
    svals = ((obs.groupdq[i, 1, :, :] & dqflags.group['SATURATED']) == 0) & ((obs.groupdq[i, 2, :, :] & dqflags.group['SATURATED']) > 0)
    diff1 = (obs.data[i, 0, :, :])[svals]
    diff2 = (obs.data[i, 1, :, :])[svals] - (obs.data[i, 0, :, :])[svals]
    
    ax[i].hist2d(diff2, diff1/diff2, range=[[20000., 40000.], [0.8, 1.2]], bins=[50, 50], cmap="afmhot")
    
    ax[i].set_title(f"Integration {i+1}")

axes[0, 0].set_ylabel("Diff1/Diff2")
axes[1, 0].set_ylabel("Diff1/Diff2")
axes[1, 1].set_xlabel("Diff2 [DN/group]")
axes[1, 0].set_xlabel("Diff2 [DN/group]")

fig.tight_layout()
plt.savefig("diff1_diff2_by_integration_onlygroup1.png")

# %%
# plot by integration
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
ax = axes.flatten()

for i in range(4):
    # find pixels that are fainter to see what happens for non saturating pixels
    diff1b = obs.data[i, 0, :, :]
    diff2b = obs.data[i, 1, :, :] - obs.data[i, 0, :, :]
    
    newlen = diff1b.shape[0] * diff1b.shape[1]
    diff1b = np.reshape(diff1b, newlen)
    diff2b = np.reshape(diff2b, newlen)
    
    ax[i].hist2d(diff1b, diff1b/diff2b, range=[[500., 40000.], [0.5, 2.5]], bins=[50, 50], cmap="afmhot")
    
    ax[i].set_title(f"Integration {i+1}")

axes[0, 0].set_ylabel("Diff1/Diff2")
axes[1, 0].set_ylabel("Diff1/Diff2")
axes[1, 1].set_xlabel("Diff2 [DN/group]")
axes[1, 0].set_xlabel("Diff2 [DN/group]")

fig.tight_layout()
plt.savefig("diff1_diff2_by_integration_faint_onlygroup1.png")
# Out:
# 2024-11-13 10:40:14,358 - stpipe - WARNING - /tmp/ipykernel_178277/3870553025.py:14: RuntimeWarning: divide by zero encountered in divide
#   ax[i].hist2d(diff1b, diff1b/diff2b, range=[[500., 40000.], [0.5, 2.5]], bins=[50, 50], cmap="afmhot")
